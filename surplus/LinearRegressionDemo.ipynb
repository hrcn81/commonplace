# %% [markdown]
# <a href="https://colab.research.google.com/github/hrcn81/commonplace/blob/main/LinearRegressionDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Function to calculate m and b
def linear_regression(X,y):
  x_mean = np.mean(X)
  y_mean = np.mean(y)
  numerator = np.sum((X - x_mean) * (y - y_mean))
  denominator = np.sum((X - x_mean) ** 2)
  m = numerator / denominator
  b = y_mean - (m * x_mean)
  return m,b

# %%
# Function for prediction
def predict(X,m,b):
  return m * X + b

# %%
# Function to calculate prediction
def rmse(y_true,y_pred):
  return np.sqrt(np.mean((y_true - y_pred) ** 2))

X = np.array([7,9.5,13,24])
Y = np.array([195,475,595,1350])

# %%
# Training model
m,b = linear_regression(X,Y)

# %%
# Making Mmodel
predictions = predict(X,m,b)

# %%
# Calculate RMSE
error = rmse(Y,predictions)

# %%
print('Slope (m)     : ',m)
print('Intercdpt (b) : ',b)
print('Predictions   : ',predictions)
print('RMSE          : ',error)
# Out:
# Slope (m)     :  65.42793627269359
# Intercdpt (b) :  -221.34864764727672
# Predictions   :  [ 236.64690626  400.21674694  629.2145239  1348.9218229 ]
# RMSE          :  46.09445696153423

# %%
plt.scatter(X,Y,color = 'blue',label = 'Data Points')
plt.plot(X,predictions,color = 'red',label = 'Regression Line')
plt.xlabel('Independent X')
plt.ylabel('Dependent Y')
plt.title('Liner Regression Model')
plt.legend()
plt.show()
