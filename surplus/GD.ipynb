# %% [markdown]
# <a href="https://colab.research.google.com/github/hrcn81/commonplace/blob/main/surplus/GD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# %%
X = np.array([[7],[9.5],[13],[18],[24]])
y = np.array([195,325,725,900,980])

print(X)
print(y)

plt.scatter(X,y)
plt.show()
# Out:
# [[ 7. ]
#  [ 9.5]
#  [13. ]
#  [18. ]
#  [24. ]]
# [195 325 725 900 980]

# %%
reg = LinearRegression()
reg.fit(X,y)

print('reg.coef_:',reg.coef_)
print('reg.intercept:',reg.intercept_)
# plt.scatter(X,y)

m = reg.coef_[0]

m
# Out:
# reg.coef_: [47.9547901]
# reg.intercept: -60.75349838536067
# 47.95479009687837

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red')

# %%
y_pred = ((m*X) + 300)

print('\n',y_pred,'\n')

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred,color = 'green',label = 'b = 0')
plt.legend()
plt.show()

b = 300
loss_slope = -2*np.sum(y - m*X.ravel() - b)
print('\n',loss_slope,'\n')

learning_rate = 0.1
step_size = loss_slope*learning_rate
print('\n',step_size,'\n')

b = b - step_size
print('\n',b,'\n')

y_pred1 = ((m*X) + b).reshape(5)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred1,color = 'green',label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = 'blue',label = 'b = 0')
plt.legend()
plt.show()
# Out:
#  [[ 635.68353068]
#  [ 755.57050592]
#  [ 923.41227126]
#  [1163.18622174]
#  [1450.91496233]]
#  3607.5349838536067
#
#
#  360.7534983853607
#
#
#  -60.75349838536067

# %%
y_pred = ((m*X) + 150)

print('\n',y_pred,'\n')

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred,color = 'green',label = 'b = 0')
plt.legend()
plt.show()

b = 150
loss_slope = -2*np.sum(y - m*X.ravel() - b)
print('\n',loss_slope,'\n')

learning_rate = 0.1
step_size = loss_slope*learning_rate
print('\n',step_size,'\n')

b = b - step_size
print('\n',b,'\n')

y_pred1 = ((m*X) + b).reshape(5)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
# plt.plot(X,y_pred1,color = 'green',label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = 'blue',label = 'b = 0')
plt.plot(X, y_pred1, color='green', label='b = {:.2f}, lr = {:.2f}'.format(b, learning_rate))
plt.legend()
plt.show()
# Out:
#  [[ 485.68353068]
#  [ 605.57050592]
#  [ 773.41227126]
#  [1013.18622174]
#  [1300.91496233]]
#  2107.5349838536067
#
#
#  210.75349838536067
#
#
#  -60.75349838536067

# %%
y_pred = ((m*X) + 150)

print('\n',y_pred,'\n')

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
plt.plot(X,y_pred,color = 'green',label = 'b = 0')
plt.legend()
plt.show()

b = 150
loss_slope = -2*np.sum(y - m*X.ravel() - b)
print('\n',loss_slope,'\n')

learning_rate = 0.01
step_size = loss_slope*learning_rate
print('\n',step_size,'\n')

b = b - step_size
print('\n',b,'\n')

y_pred1 = ((m*X) + b).reshape(5)

plt.scatter(X,y)
plt.plot(X,reg.predict(X),color = 'red',label = 'OLS')
# plt.plot(X,y_pred1,color = 'green',label = 'b = {}'.format(b))
plt.plot(X,y_pred,color = 'blue',label = 'b = 0')
plt.plot(X, y_pred1, color='green', label='b = {:.2f}, lr = {:.2f}'.format(b, learning_rate))
plt.legend()
plt.show()
# Out:
#  [[ 485.68353068]
#  [ 605.57050592]
#  [ 773.41227126]
#  [1013.18622174]
#  [1300.91496233]]
#  2107.5349838536067
#
#
#  21.075349838536066
#
#
#  128.92465016146394
